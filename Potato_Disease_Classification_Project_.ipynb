# %% [markdown]
# <a href="https://colab.research.google.com/github/Asim347/AI-ML_Projects/blob/main/Potato_Disease_Classification_Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
import cv2
import tensorflow as tf
from tensorflow import keras

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.listdir('/content/drive/MyDrive')
# Out:
# ['Classroom',
#  'C++',
#  'file1',
#  'Asim Ali - GITHUB DOCUMENT.gdoc',
#  'Asim_ali.docx',
#  'PROGRAMMING FUNDAMENTALS TASK.docx',
#  'MOTHERBOARD.pptx',
#  'bill calulation.cpp',
#  'graded assignment',
#  'traffic_light.cpp',
#  'ungraded',
#  'for loop',
#  'Functions Task for Home.gdoc',
#  'occurenece.cpp',
#  'reverse_array.cpp',
#  'sum.cpp',
#  'search_element.cpp',
#  'reverse.cpp',
#  'max_min.cpp',
#  'ali_haider.css',
#  'Untitled document (4).gdoc',
#  'Download Europass cv sample template in ms word (1).gdoc',
#  'Download Europass cv sample template in ms word.gdoc',
#  '12_certificate (1).pdf',
#  '12_DMC.pdf',
#  'Slide set_05 - Pointers.gdoc',
#  'MARKS vs MIND.gslides',
#  'Payment.cpp',
#  'Project.docx',
#  'Smart Pharmacy App - Technology & Tools Document.gdoc',
#  'Asim_Ali_Analysis.gdoc',
#  'asim.gdoc',
#  'experience_certificate.gdoc',
#  'unedit.gdoc',
#  'Malik Muhammad Umair CV.gdoc',
#  'Untitled document (3).gdoc',
#  'OWN ANSER.gdoc',
# ...

# %%
folder_path = "/content/drive/MyDrive/PotatoDisease"

os.listdir(folder_path)
# Out:
# ['Potato___healthy', 'Potato___Late_blight', 'Potato___Early_blight']

# %%
import os

healthy_path = "/content/drive/MyDrive/PotatoDisease/Potato___healthy"

os.listdir(healthy_path)[:5]
# Out:
# ['03da9931-e514-4cc7-b04a-8f474a133ce5___RS_HL 1830.JPG',
#  '00fc2ee5-729f-4757-8aeb-65c3355874f2___RS_HL 1864.JPG',
#  '04481ca2-f94c-457e-b785-1ac05800b7ec___RS_HL 1930.JPG',
#  '1ae826e2-5148-47bd-a44c-711ec9cc9c75___RS_HL 1954.JPG',
#  '14484ea5-9c34-427c-abe4-2743265aced0___RS_HL 4204.JPG']

# %%
for folder in os.listdir(folder_path):
    path = os.path.join(folder_path, folder)
    print(folder, len(os.listdir(path)))
# Out:
# Potato___healthy 152
# Potato___Late_blight 847
# Potato___Early_blight 78

# %%
healthy_path = "/content/drive/MyDrive/PotatoDisease/Potato___healthy"

# get first image
img_name = os.listdir(healthy_path)[0]

# full path
img_path = os.path.join(healthy_path, img_name)

# open and display
img = Image.open(img_path)

plt.imshow(img)
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(10,5))

for i, img_name in enumerate(os.listdir(healthy_path)[:5]):
    img = Image.open(os.path.join(healthy_path, img_name))

    plt.subplot(1,5,i+1)
    plt.imshow(img)
    plt.axis("off")

plt.show()
